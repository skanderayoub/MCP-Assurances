# %%
import json

with open("./code_assurances.json", "r", encoding="utf-8") as f:
    data = json.load(f)
    
data.keys()
# Out:
# dict_keys(['articles', 'hierarchy_tree'])

# %%
articles = data["articles"]
articles[0].keys()
# Out:
# dict_keys(['article_id', 'content', 'hierarchy', 'references', 'referenced_by', 'summary', 'keywords', 'page_number'])

# %%
articles[1]
# Out:
# {'article_id': 'Article L111-1',
#  'content': "Les titres Ier, II et III du présent livre ne concernent que les assurances terrestres. A l'exception des articles L. 111-6, L. 112-2, L. 112-4, L. 112-7 et L. 113-4-1, ils ne sont applicables ni aux contrats d'assurance régis par le titre VII du présent livre ni aux opérations d'assurance crédit ; les opérations de réassurance conclues entre assureurs et réassureurs sont exclues de leur champ d'application.      Il n'est pas dérogé aux dispositions des lois et règlements relatifs aux sociétés à forme tontinière ; aux assurances contractées par les chefs d'entreprise, à raison de la responsabilité des accidents de travail survenus à leurs ouvriers et employés ; aux sociétés ou caisses d'assurances et de réassurances mutuelles agricoles.",
#  'hierarchy': {'partie': 'Partie législative',
#   'livre': 'Livre Ier : Le contrat',
#   'titre': 'Titre Ier : Règles communes aux assurances de dommages et aux assurances de personnes',
# ...

# %%
hierarchy = data["hierarchy_tree"]
hierarchy
# Out:
# {'Partie législative': {'Livre Ier : Le contrat': {'articles': ['Article L100-1'],
#    'Titre Ier : Règles communes aux assurances de dommages et aux assurances de personnes': {'Chapitre Ier : Dispositions générales.': {'articles': ['Article L111-1',
#       'Article L111-2',
#       'Article L111-3',
#       'Article L111-4',
#       'Article L111-6',
#       'Article L111-7',
#       'Article L111-8',
#       'Article L111-9',
#       'Article L111-10',
#       'Article L111-11',
#       'Article L111-12']},
#     "Chapitre II : Conclusion et preuve du contrat d'assurance - Forme et transmission des polices.": {'articles': ['Article L112-1',
#       'Article L112-2',
#       'Article L112-2-1',
#       'Article L112-2-2',
#       'Article L112-3',
#       'Article L112-4',
#       'Article L112-5',
#       'Article L112-6',
#       'Article L112-7',
#       'Article L112-8',
#       'Article L112-9',
#       'Article L112-10',
#       'Article L112-11']},
# ...

# %%
import random
rand_articles = random.sample(articles, 3)

small_data = {
    "articles": rand_articles,
    "hierarchy_tree": ""
}

with open("./code_assurances_small.json", "w", encoding="utf-8") as f:
    json.dump(small_data, f, ensure_ascii=False, indent=2)
